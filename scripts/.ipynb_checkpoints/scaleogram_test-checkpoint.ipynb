# %%
import matplotlib.pyplot as plt
#%matplotlib inline
import scaleogram as scg
import seaborn as sns
import sys

print("TEST notebook for scaleogram version="+scg.__version__+
      " python version="+sys.version)
# Out:
# TEST notebook for scaleogram version=0.9.5 python version=3.10.8 (tags/v3.10.8:aaaf517, Oct 11 2022, 16:50:30) [MSC v.1933 64 bit (AMD64)]

# %%
plt.rcParams['figure.figsize'] = [14,6]
plt.rcParams['font.size'] = 14.0
scg.test_cws()
# Out:
# Multi-purpose test demo (needs graphic output for matplotlib)
#   Plot cmor1-1.5 wavelet in time and frequency domains
#   Plot scaleogram of a gaussian
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 plt.rcParams['figure.figsize'] = [14,6]
#       2 plt.rcParams['font.size'] = 14.0
# ----> 3 scg.test_cws()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\pcce-wavelets-alGG9JU1-py3.10\lib\site-packages\scaleogram\test.py:41, in test_cws()
#      38 #    cws(signal) # KISS
#      40     scales = np.arange(1, 200, 2)
# ---> 41     cwt = CWT(time, signal, scales, 'cmor1-1.5')
#      42     ax = cws(cwt,
#      43               wavelet=get_default_wavelet(),
#      44               #yaxis='frequency',
#    (...)
#      50               #ylim=(40, 20),
#      51               )
#      52     plt.tight_layout()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\pcce-wavelets-alGG9JU1-py3.10\lib\site-packages\scaleogram\cws.py:85, in CWT.__init__(self, time, signal, scales, wavelet)
#      83 # Compute CWT
#      84 dt = time[1]-time[0]
# ---> 85 coefs, scales_freq = CWT_FUN(signal, scales, wavelet, dt)
#      86 # Note about frequencies values:
#      87 #   The value returned by PyWt is
#      88 #      scales_freq = wavelet.central_frequency / scales
#      89 #   If the time array is not provided it is expressed in
#      90 #   Nb of oscillations over the whole signal array
#      92 self.signal = signal
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\pcce-wavelets-alGG9JU1-py3.10\lib\site-packages\scaleogram\wfun.py:189, in fastcwt(data, scales, wavelet, sampling_period, method)
#     184 if method in ('auto', 'fft'):
#     185     # - to be as large as the sum of data length and and maximum wavelet
#     186     #   support to avoid circular convolution effects
#     187     # - additional padding to reach a power of 2 for CPU-optimal FFT
#     188     size_pad = lambda s: 2**np.int(np.ceil(np.log2(s[0] + s[1])))
# --> 189     size_scale0 = size_pad( (len(data),
#     190                              np.take(scales, 0) * ((x[-1] - x[0]) + 1)) )
#     191     fft_data = None
#     192 elif not method == 'conv':
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\pcce-wavelets-alGG9JU1-py3.10\lib\site-packages\scaleogram\wfun.py:188, in fastcwt.<locals>.<lambda>(s)
#     182 int_psi, x = pywt.integrate_wavelet(wavelet, precision=precision)
#     184 if method in ('auto', 'fft'):
#     185     # - to be as large as the sum of data length and and maximum wavelet
#     186     #   support to avoid circular convolution effects
#     187     # - additional padding to reach a power of 2 for CPU-optimal FFT
# --> 188     size_pad = lambda s: 2**np.int(np.ceil(np.log2(s[0] + s[1])))
#     189     size_scale0 = size_pad( (len(data),
#     190                              np.take(scales, 0) * ((x[-1] - x[0]) + 1)) )
#     191     fft_data = None
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\pcce-wavelets-alGG9JU1-py3.10\lib\site-packages\numpy\__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
scg.plot_wavelets()

# %%
help(scg.test_cws)
# Out:
# Help on function test_cws in module scaleogram.test:
#
# test_cws()
#     Graphical output test function
